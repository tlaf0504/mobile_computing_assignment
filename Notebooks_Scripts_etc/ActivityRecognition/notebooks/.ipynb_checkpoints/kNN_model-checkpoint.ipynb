# %%
import sys
import os
import glob
import ipdb
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import metrics

# %%
data_directory = os.path.join("..", "data", "kNN")
activities = [
    {"name": "Biceps Curls",
     "subdirectory": "biceps_curls",
     "label": 0},
    {"name": "Triceps Curls",
     "subdirectory": "triceps_curls",
     "label": 1},
    {"name": "Russian Twists",
     "subdirectory": "russian_twists",
     "label": 2},
    {"name": "Crunches",
     "subdirectory": "crunches",
     "label": 3}]

VALIDATION_SPLIT = 0.25

# %%
dataset_samples = 0
dataset_label_strings = []
N_activities = 4


for activity in activities:
  subdir = os.path.join(data_directory, activity["subdirectory"], "timeframes")
  N_samples = int(len(os.listdir(subdir)) / 2) # Two files per sample (Accelerometer & Gyroscope)
  dataset_samples += N_samples

print(f"The dataset contains in total {dataset_samples} samples.")
# Out:
# The dataset contains in total 529 samples.

# %%
for k in range(N_activities):
  dataset_label_strings.append(activities[k]["name"])
dataset_label_strings
# Out:
# ['Biceps Curls', 'Triceps Curls', 'Russian Twists', 'Crunches']

# %%
dataset_x = np.zeros((dataset_samples, 200, 6))
dataset_y = np.zeros(dataset_samples, dtype=int)

# %%
def sensor_data_normalization(data):
  mean_vals = np.mean(data, axis=0)
  return data - mean_vals
  #return data

# %%
sample_idx = 0
for activity in activities:
  name = activity["name"]
  subdirectory = os.path.join(data_directory, activity["subdirectory"])
  label = int(activity["label"])

  gyro_filenames = glob.glob(os.path.join(subdirectory, "timeframes", "*_gyro_sensor_data_*.npy"))
  for gyro_file in gyro_filenames:
    print("Loading {:6d} from {:6d}".format(sample_idx, dataset_samples))
    accel_file = gyro_file.replace("gyro", "accel")

    gyro_data = np.load(os.path.join(gyro_file), allow_pickle=True)
    accel_data = np.load(os.path.join(accel_file), allow_pickle=True)

    gyro_data_normalized = sensor_data_normalization(gyro_data[:,1:])
    accel_data_normalized = sensor_data_normalization(accel_data[:,1:])

    dataset_x[sample_idx, :, 0:3] = gyro_data_normalized
    dataset_x[sample_idx, :, 3:6] = accel_data_normalized

    dataset_y[sample_idx] = label
    sample_idx += 1
# Out:
# Loading      0 from    529
# Loading      1 from    529
# Loading      2 from    529
# Loading      3 from    529
# Loading      4 from    529
# Loading      5 from    529
# Loading      6 from    529
# Loading      7 from    529
# Loading      8 from    529
# Loading      9 from    529
# Loading     10 from    529
# Loading     11 from    529
# Loading     12 from    529
# Loading     13 from    529
# Loading     14 from    529
# Loading     15 from    529
# Loading     16 from    529
# Loading     17 from    529
# Loading     18 from    529
# Loading     19 from    529
# Loading     20 from    529
# Loading     21 from    529
# Loading     22 from    529
# Loading     23 from    529
# Loading     24 from    529
# Loading     25 from    529
# Loading     26 from    529
# Loading     27 from    529
# Loading     28 from    529
# Loading     29 from    529
# Loading     30 from    529
# Loading     31 from    529
# Loading     32 from    529
# Loading     33 from    529
# Loading     34 from    529
# Loading     35 from    529
# Loading     36 from    529
# Loading     37 from    529
# Loading     38 from    529
# Loading     39 from    529
# Loading     40 from    529
# Loading     41 from    529
# Loading    178 from    529
# Loading    179 from    529
# Loading    180 from    529
# Loading    181 from    529
# Loading    182 from    529
# Loading    183 from    529
# Loading    184 from    529
# Loading    185 from    529
# Loading    186 from    529
# Loading    187 from    529
# Loading    188 from    529
# Loading    189 from    529
# Loading    190 from    529
# Loading    191 from    529
# Loading    192 from    529
# Loading    193 from    529
# Loading    194 from    529
# Loading    195 from    529
# Loading    196 from    529
# Loading    197 from    529
# Loading    198 from    529
# Loading    199 from    529
# Loading    200 from    529
# Loading    201 from    529
# Loading    202 from    529
# Loading    203 from    529
# Loading    204 from    529
# Loading    205 from    529
# Loading    206 from    529
# Loading    207 from    529
# Loading    208 from    529
# Loading    209 from    529
# Loading    210 from    529
# Loading    211 from    529
# Loading    212 from    529
# Loading    213 from    529
# Loading    214 from    529
# Loading    215 from    529
# Loading    216 from    529
# Loading    217 from    529
# Loading    218 from    529
# Loading    219 from    529
# Loading    220 from    529
# Loading    221 from    529
# Loading    222 from    529
# Loading    223 from    529
# Loading    224 from    529
# Loading    225 from    529
# Loading    226 from    529
# Loading    227 from    529
# Loading    228 from    529
# Loading    229 from    529
# Loading    230 from    529
# Loading    231 from    529
# Loading    232 from    529
# Loading    233 from    529
# Loading    234 from    529
# Loading    235 from    529
# Loading    236 from    529
# Loading    237 from    529
# Loading    238 from    529
# Loading    239 from    529
# Loading    240 from    529
# Loading    241 from    529
# Loading    242 from    529
# Loading    243 from    529
# Loading    244 from    529
# Loading    245 from    529
# Loading    246 from    529
# Loading    247 from    529
# Loading    248 from    529
# Loading    249 from    529
# Loading    250 from    529
# Loading    251 from    529
# Loading    252 from    529
# Loading    253 from    529
# Loading    254 from    529
# Loading    255 from    529
# Loading    256 from    529
# Loading    257 from    529
# Loading    258 from    529
# Loading    259 from    529
# Loading    260 from    529
# Loading    261 from    529
# Loading    262 from    529
# Loading    263 from    529
# Loading    264 from    529
# Loading    265 from    529
# Loading    266 from    529
# Loading    267 from    529
# Loading    268 from    529
# Loading    269 from    529
# Loading    270 from    529
# Loading    271 from    529
# Loading    272 from    529
# Loading    273 from    529
# Loading    274 from    529
# Loading    275 from    529
# Loading    276 from    529
# Loading    277 from    529
# Loading    278 from    529
# Loading    279 from    529
# Loading    280 from    529
# Loading    281 from    529
# Loading    282 from    529
# Loading    283 from    529
# Loading    284 from    529
# Loading    285 from    529
# Loading    286 from    529
# Loading    287 from    529
# Loading    288 from    529
# Loading    289 from    529
# Loading    290 from    529
# Loading    291 from    529
# Loading    292 from    529
# Loading    293 from    529
# Loading    294 from    529
# Loading    295 from    529
# Loading    296 from    529
# Loading    297 from    529
# Loading    298 from    529
# Loading    299 from    529
# Loading    300 from    529
# Loading    301 from    529
# Loading    302 from    529
# Loading    303 from    529
# Loading    304 from    529
# Loading    305 from    529
# Loading    306 from    529
# Loading    307 from    529
# Loading    308 from    529
# Loading    309 from    529
# Loading    310 from    529
# Loading    311 from    529
# Loading    312 from    529
# Loading    313 from    529
# Loading    449 from    529
# Loading    450 from    529
# Loading    451 from    529
# Loading    452 from    529
# Loading    453 from    529
# Loading    454 from    529
# Loading    455 from    529
# Loading    456 from    529
# Loading    457 from    529
# Loading    458 from    529
# Loading    459 from    529
# Loading    460 from    529
# Loading    461 from    529
# Loading    462 from    529
# Loading    463 from    529
# Loading    464 from    529
# Loading    465 from    529
# Loading    466 from    529
# Loading    467 from    529
# Loading    468 from    529
# Loading    469 from    529
# Loading    470 from    529
# Loading    471 from    529
# Loading    472 from    529
# Loading    473 from    529
# Loading    474 from    529
# Loading    475 from    529
# Loading    476 from    529
# Loading    477 from    529
# Loading    478 from    529
# Loading    479 from    529
# Loading    480 from    529
# Loading    481 from    529
# Loading    482 from    529
# Loading    483 from    529
# Loading    484 from    529
# Loading    485 from    529
# Loading    486 from    529
# Loading    487 from    529
# Loading    488 from    529
# Loading    489 from    529
# Loading    490 from    529
# Loading    491 from    529
# Loading    492 from    529
# Loading    493 from    529
# Loading    494 from    529
# Loading    495 from    529
# Loading    496 from    529
# Loading    497 from    529
# Loading    498 from    529
# Loading    499 from    529
# Loading    500 from    529
# Loading    501 from    529
# Loading    502 from    529
# Loading    503 from    529
# Loading    504 from    529
# Loading    505 from    529
# Loading    506 from    529
# Loading    507 from    529
# Loading    508 from    529
# Loading    509 from    529
# Loading    510 from    529
# Loading    511 from    529
# Loading    512 from    529
# Loading    513 from    529
# Loading    514 from    529
# Loading    515 from    529
# Loading    516 from    529
# Loading    517 from    529
# Loading    518 from    529
# Loading    519 from    529
# Loading    520 from    529
# Loading    521 from    529
# Loading    522 from    529
# Loading    523 from    529
# Loading    524 from    529
# Loading    525 from    529
# Loading    526 from    529
# Loading    527 from    529
# Loading    528 from    529

# %%
def calc_energies(data):
    N_samples = data.shape[0]
    return np.var(data,axis=0) / N_samples

# %% [markdown]
# ### Split dataset into training- and validation set

# %%
from numpy.random import default_rng
rng = default_rng(seed=1234) # Use seed for reproducability

N_validation_samples = int(np.floor(dataset_samples * VALIDATION_SPLIT))
N_training_samples = dataset_samples - N_validation_samples

validation_set_indices = np.zeros((N_validation_samples), dtype=int)
# Get N_validation_samples unique indices for the validation set
for k in range(N_validation_samples):
  idx_tmp = rng.integers(low=0, high=dataset_samples - 1, size=1)
  while idx_tmp in validation_set_indices:
    idx_tmp = rng.integers(low=0, high=dataset_samples - 1, size=1)
  validation_set_indices[k] = idx_tmp

validation_set_boolean_indices = np.zeros(dataset_samples, dtype=bool)
validation_set_boolean_indices[validation_set_indices] = True
training_set_boolean_indices = ~validation_set_boolean_indices


x_train = dataset_x[training_set_boolean_indices, :]
y_train = dataset_y[training_set_boolean_indices]

x_validate = dataset_x[validation_set_boolean_indices, :]
y_validate = dataset_y[validation_set_boolean_indices]

# %% [markdown]
# ### Training-Set histogram

# %%
sns.histplot(data=y_train, stat="count", discrete=True, bins=N_activities)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ### Validation-Set histogram

# %%
sns.histplot(data=y_validate, stat="count", discrete=True, bins=N_activities)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ### Pair-plot of training-set

# %%
x_train_energies = np.zeros((N_training_samples,6))
for k in range(N_training_samples):
    x_train_energies[k,:] = calc_energies(x_train[k,:,:])

df = pd.DataFrame(x_train_energies, columns=["Gyro X", "Gyro Y", "Gyro Z", "Accel X", "Accel Y", "Accel Z"])
df["label"] = list(map(lambda x: activities[x]["name"], y_train))

sns.pairplot(df, hue="label")

# %% [markdown]
# ### Store reference-data to file
# This file is then moved to the device and loaded at runtime for the kNN classification.

# %%
out_filename = os.path.join("..", "data", "kNN", "kNN_reference_data.csv")
data_stackes = np.column_stack((x_train_energies, y_train))
np.savetxt()

# %% [markdown]
# # Validate model

# %% [markdown]
# ## Pair-plot of validation-set

# %%
x_validate_energies = np.zeros((N_validation_samples,6))
for k in range(N_validation_samples):
    x_validate_energies[k,:] = calc_energies(x_validate[k,:,:])

df = pd.DataFrame(x_validate_energies, columns=["Gyro X", "Gyro Y", "Gyro Z", "Accel X", "Accel Y", "Accel Z"])
df["label"] = list(map(lambda x: activities[x]["name"], y_validate))

sns.pairplot(df, hue="label")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-228acf9250f4> in <module>
#       6 df["label"] = list(map(lambda x: activities[x]["name"], y_validate))
#       7
# ----> 8 sns.pairplot(df, hue="label", delimiter=";", fmt="%e;%e;%e;%e;%e;%e;%d")
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: pairplot() got an unexpected keyword argument 'delimiter'

# %% [markdown]
# ### Predict classes

# %%
def kNN(features_in, features_ref, labels_ref, k=10, N_classes=4):
    euclidian_distances = np.linalg.norm(features_ref - features_in, axis=1)
    sorted_indices = np.argsort(euclidian_distances)
    sorted_labels = labels_ref[sorted_indices]
    
    return k_majority_voting(sorted_labels, N_classes = N_classes, k = k)
    
def k_majority_voting(data, k, N_classes):
    counters = np.zeros((N_classes), dtype=int)
    N_entries = data.shape[0]
    for l in range(k):
        counters[data[l]] += 1
        
    sorted_indices = np.argsort(counters)
    return sorted_indices[-1]

# %%
y_validate_predicted = np.zeros((N_validation_samples), dtype=int)

for k in range(N_validation_samples):
    y_validate_predicted[k] = kNN(
        features_in = x_validate_energies[k,:], 
        features_ref = x_train_energies, 
        labels_ref = y_train, # Labels are 1-based, but are assumed to be 0-based
        k = 10,
        N_classes = 4)

# %%
def show_confusion_matrix(validations, predictions, labels_strings):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(matrix,
                cmap='coolwarm',
                linecolor='white',
                linewidths=1,
                xticklabels=labels_strings,
                yticklabels=labels_strings,
                annot=True,
                fmt='d')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
show_confusion_matrix(
    validations = y_validate, 
    predictions = y_validate_predicted, 
    labels_strings = df["label"].unique())

# %%
df["label"].unique()
# Out:
# array(['Biceps Curls', 'Triceps Curls', 'Russian Twists', 'Crunches'],
#       dtype=object)

# %% [markdown]
# ## Store validation-set for On-Device testing

# %%
test_set_dir = os.path.join("..", "data", "kNN", "validation_set")
if os.path.isdir(test_set_dir):
    shutil.rmtree(test_set_dir)
os.mkdir(test_set_dir)

for k in range(x_validate.shape[0]):
  filename = test_set_dir + "/sample_{:d}_activity_{:d}.csv".format(k, y_validate[k])
  np.savetxt(filename, x_validate[k,:,:], delimiter=";")
